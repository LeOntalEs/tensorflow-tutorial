# %%
import gym
import numpy as np
import random
import math
from time import sleep


## Initialize the "Cart-Pole" environment
env = gym.make('CartPole-v0')

## Defining the environment related constants

# Number of discrete states (bucket) per state dimension
NUM_BUCKETS = (1, 1, 6, 3)  # (x, x', theta, theta')
# Number of discrete actions
NUM_ACTIONS = env.action_space.n # (left, right)
# Bounds for each discrete state
STATE_BOUNDS = list(zip(env.observation_space.low, env.observation_space.high))
STATE_BOUNDS[1] = [-0.5, 0.5]
STATE_BOUNDS[3] = [-math.radians(50), math.radians(50)]
# Index of the action
ACTION_INDEX = len(NUM_BUCKETS)

## Creating a Q-Table for each state-action pair
q_table = np.zeros(NUM_BUCKETS + (NUM_ACTIONS,))

## Learning related constants
MIN_EXPLORE_RATE = 0.01
MIN_LEARNING_RATE = 0.1

## Defining the simulation related constants
NUM_EPISODES = 1000
MAX_T = 250
STREAK_TO_END = 120
SOLVED_T = 199
DEBUG_MODE = True

def simulate():

    ## Instantiating the learning related parameters
    learning_rate = get_learning_rate(0)
    explore_rate = get_explore_rate(0)
    discount_factor = 0.99  # since the world is unchanging

    num_streaks = 0

    for episode in range(NUM_EPISODES):

        # Reset the environment
        obv = env.reset()

        # the initial state
        state_0 = state_to_bucket(obv)

        for t in range(MAX_T):
            env.render()

            # Select an action
            action = select_action(state_0, explore_rate)

            # Execute the action
            obv, reward, done, _ = env.step(action)

            # Observe the result
            state = state_to_bucket(obv)

            # Update the Q based on the result
            best_q = np.amax(q_table[state])
            q_table[state_0 + (action,)] += learning_rate*(reward + discount_factor*(best_q) - q_table[state_0 + (action,)])

            # Setting up for the next iteration
            state_0 = state

            # Print data
            if (DEBUG_MODE):
                print("\nEpisode = %d" % episode)
                print("t = %d" % t)
                print("Action: %d" % action)
                print("State: %s" % str(state))
                print("Reward: %f" % reward)
                print("Best Q: %f" % best_q)
                print("Explore rate: %f" % explore_rate)
                print("Learning rate: %f" % learning_rate)
                print("Streaks: %d" % num_streaks)

                print("")

            if done:
                print("Episode %d finished after %f time steps" % (episode, t))
                if (t >= SOLVED_T):
                    num_streaks += 1
                else:
                    num_streaks = 0
                break

            #sleep(0.25)

        # It's considered done when it's solved over 120 times consecutively
        if num_streaks > STREAK_TO_END:
            break

        # Update parameters
        explore_rate = get_explore_rate(episode)
        learning_rate = get_learning_rate(episode)


def select_action(state, explore_rate):
    # Select a random action
    if random.random() < explore_rate:
        action = env.action_space.sample()
    # Select the action with the highest q
    else:
        action = np.argmax(q_table[state])
    return action


def get_explore_rate(t):
    return max(MIN_EXPLORE_RATE, min(1, 1.0 - math.log10((t+1)/25)))

def get_learning_rate(t):
    return max(MIN_LEARNING_RATE, min(0.5, 1.0 - math.log10((t+1)/25)))

def state_to_bucket(state):
    bucket_indice = []
    for i in range(len(state)):
        if state[i] <= STATE_BOUNDS[i][0]:
            bucket_index = 0
        elif state[i] >= STATE_BOUNDS[i][1]:
            bucket_index = NUM_BUCKETS[i] - 1
        else:
            # Mapping the state bounds to the bucket array
            bound_width = STATE_BOUNDS[i][1] - STATE_BOUNDS[i][0]
            offset = (NUM_BUCKETS[i]-1)*STATE_BOUNDS[i][0]/bound_width
            scaling = (NUM_BUCKETS[i]-1)/bound_width
            bucket_index = int(round(scaling*state[i] - offset))
        bucket_indice.append(bucket_index)
    return tuple(bucket_indice)

if __name__ == "__main__":
    simulate()
# Out:
# Episode = 0
# t = 0
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 0.000000
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 0
# t = 1
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 0.500000
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 0
# t = 2
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 0.747500
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 0
# t = 3
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 1.243763
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 0
# t = 4
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 1.365662
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 0
# t = 5
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 0.000000
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 0
# t = 6
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 0.000000
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 0
# t = 7
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 0.500000
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 0
# t = 8
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 0.997500
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 0
# t = 9
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 1.492513
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 0
# t = 10
# Action: 1
# State: (0, 0, 1, 0)
# Reward: 1.000000
# Best Q: 0.000000
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 0
# t = 11
# Action: 0
# State: (0, 0, 1, 0)
# Reward: 1.000000
# Best Q: 0.000000
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
# Episode 0 finished after 11.000000 time steps
#
# Episode = 1
# t = 0
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 1.398942
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 1
# t = 1
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 1.875308
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 1
# t = 2
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 2.127748
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 1
# t = 3
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 0.000000
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 1
# t = 4
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 0.000000
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 1
# t = 5
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 0.500000
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 1
# t = 6
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 0.000000
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 1
# t = 7
# Action: 1
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 0.000000
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 1
# t = 8
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 0.500000
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 1
# t = 9
# Action: 1
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 0.747500
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 1
# t = 10
# Action: 1
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 1.120013
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 1
# t = 11
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 1.614412
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 1
# t = 12
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 1.672884
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 1
# t = 13
# Action: 1
# State: (0, 0, 4, 2)
# Reward: 1.000000
# Best Q: 0.000000
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 1
# t = 14
# Action: 1
# State: (0, 0, 4, 2)
# Reward: 1.000000
# Best Q: 0.000000
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 1
# t = 15
# Action: 1
# State: (0, 0, 4, 2)
# Reward: 1.000000
# Best Q: 0.500000
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
# Episode 1 finished after 15.000000 time steps
#
# Episode = 2
# t = 0
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 0.000000
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 2
# t = 1
# Action: 0
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 0.500000
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 2
# t = 2
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 0.747500
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 2
# t = 3
# Action: 0
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 1.120013
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 2
# t = 4
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 1.428156
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 2
# t = 5
# Action: 0
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 1.766944
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 2
# t = 6
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 2.088715
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 2
# t = 7
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 0.000000
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 2
# t = 8
# Action: 0
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 2.088715
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 2
# t = 9
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 1.533914
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 2
# t = 10
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 1.492525
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 2
# t = 11
# Action: 0
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 1.492525
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 2
# t = 12
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 2.127748
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 2
# t = 13
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 2.172635
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 2
# t = 14
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 2.639329
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 2
# t = 15
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 2.892785
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 2
# t = 16
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 2.892785
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 2
# t = 17
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 2.892785
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 2
# t = 18
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 3.271024
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 2
# t = 19
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 3.754669
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 2
# t = 20
# Action: 0
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 4.235896
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 2
# t = 21
# Action: 1
# State: (0, 0, 1, 0)
# Reward: 1.000000
# Best Q: 0.500000
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 2
# t = 22
# Action: 0
# State: (0, 0, 1, 0)
# Reward: 1.000000
# Best Q: 0.500000
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
# Episode 2 finished after 22.000000 time steps
#
# Episode = 3
# t = 0
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 2.113634
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 3
# t = 1
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 1.533914
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 3
# t = 2
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 4.043161
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 3
# t = 3
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 4.043161
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 3
# t = 4
# Action: 0
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 4.043161
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 3
# t = 5
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 4.522945
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
# Episode = 3
# t = 6
# Action: 0
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 4.705902
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 3
# t = 7
# Action: 0
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 5.090894
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 3
# t = 8
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 5.565440
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 3
# t = 9
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 5.607844
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 3
# t = 10
# Action: 0
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 6.079805
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 3
# t = 11
# Action: 1
# State: (0, 0, 1, 0)
# Reward: 1.000000
# Best Q: 0.997500
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 3
# t = 12
# Action: 0
# State: (0, 0, 1, 0)
# Reward: 1.000000
# Best Q: 0.997500
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 3
# t = 13
# Action: 1
# State: (0, 0, 1, 0)
# Reward: 1.000000
# Best Q: 1.492513
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
# Episode 3 finished after 13.000000 time steps
#
# Episode = 4
# t = 0
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 3.251593
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 4
# t = 1
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 0.998750
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 4
# t = 2
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 2.164520
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 4
# t = 3
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 2.164520
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 4
# t = 4
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 2.653697
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 4
# t = 5
# Action: 1
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 3.140429
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 4
# t = 6
# Action: 1
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 3.140429
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 4
# t = 7
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 3.408570
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 4
# t = 8
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 3.757456
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 4
# t = 9
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 4.238669
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 4
# t = 10
# Action: 1
# State: (0, 0, 4, 2)
# Reward: 1.000000
# Best Q: 0.997500
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 4
# t = 11
# Action: 1
# State: (0, 0, 4, 2)
# Reward: 1.000000
# Best Q: 0.997500
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
# Episode 4 finished after 11.000000 time steps
#
# Episode = 5
# t = 0
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 3.251593
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 5
# t = 1
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 3.352294
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 5
# t = 2
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 3.785182
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 5
# t = 3
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 2.070812
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 5
# t = 4
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 3.785182
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 5
# t = 5
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 2.373665
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 5
# t = 6
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 3.785182
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 5
# t = 7
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 3.785182
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 5
# t = 8
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 4.266256
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 5
# t = 9
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 6.292223
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 5
# t = 10
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 6.292223
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 5
# t = 11
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 6.292223
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 5
# t = 12
# Action: 0
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 6.430392
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 5
# t = 13
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 6.829156
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 5
# t = 14
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 7.095628
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 5
# t = 15
# Action: 0
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 7.560150
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 5
# t = 16
# Action: 0
# State: (0, 0, 1, 0)
# Reward: 1.000000
# Best Q: 1.492513
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 5
# t = 17
# Action: 1
# State: (0, 0, 1, 0)
# Reward: 1.000000
# Best Q: 1.492513
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
# Episode 5 finished after 17.000000 time steps
#
# Episode = 6
# t = 0
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 5.987113
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 6
# t = 1
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 3.560498
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 6
# t = 2
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 5.987113
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 6
# t = 3
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 5.987113
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 6
# t = 4
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 6.457177
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 6
# t = 5
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 6.457177
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 6
# t = 6
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 6.924892
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 6
# t = 7
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 4.717476
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 6
# t = 8
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 2.560820
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 6
# t = 9
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 4.717476
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 6
# t = 10
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 4.717476
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 6
# t = 11
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 5.193888
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 6
# t = 12
# Action: 1
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 5.667919
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 6
# t = 13
# Action: 1
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 5.667919
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 6
# t = 14
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 5.737587
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 6
# t = 15
# Action: 1
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 6.174065
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 6
# t = 16
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 6.424956
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 6
# t = 17
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 6.767386
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 6
# t = 18
# Action: 0
# State: (0, 0, 4, 2)
# Reward: 1.000000
# Best Q: 1.492513
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 6
# t = 19
# Action: 0
# State: (0, 0, 4, 2)
# Reward: 1.000000
# Best Q: 1.492513
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
# Episode 6 finished after 19.000000 time steps
#
# Episode = 7
# t = 0
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 6.924892
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 7
# t = 1
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 7.092936
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 7
# t = 2
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 7.473449
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
# Episode = 7
# t = 3
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 7.745825
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 7
# t = 4
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 8.070908
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 7
# t = 5
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 8.368012
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 7
# t = 6
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 8.677620
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 7
# t = 7
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 7.560150
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 7
# t = 8
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 7.560150
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 7
# t = 9
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 8.022349
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 7
# t = 10
# Action: 0
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 8.482237
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 7
# t = 11
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 8.482237
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 7
# t = 12
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 8.939826
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 7
# t = 13
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 9.395127
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 7
# t = 14
# Action: 1
# State: (0, 0, 1, 0)
# Reward: 1.000000
# Best Q: 1.858191
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 7
# t = 15
# Action: 0
# State: (0, 0, 1, 0)
# Reward: 1.000000
# Best Q: 1.858191
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
# Episode 7 finished after 15.000000 time steps
#
# Episode = 8
# t = 0
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 8.809390
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 8
# t = 1
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 7.232317
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 8
# t = 2
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 8.712669
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 8
# t = 3
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 8.712669
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 8
# t = 4
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 8.996777
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 8
# t = 5
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 9.309739
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 8
# t = 6
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 9.606709
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 8
# t = 7
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 5.243870
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 8
# t = 8
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 5.243870
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 8
# t = 9
# Action: 1
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 6.424956
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 8
# t = 10
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 3.879508
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 8
# t = 11
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 5.632834
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 8
# t = 12
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 5.632834
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 8
# t = 13
# Action: 1
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 5.716037
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 8
# t = 14
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 6.145856
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 8
# t = 15
# Action: 1
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 6.400217
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 8
# t = 16
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 5.228007
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 8
# t = 17
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 5.228007
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 8
# t = 18
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 5.228007
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 8
# t = 19
# Action: 0
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 5.272000
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 8
# t = 20
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 6.458381
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 8
# t = 21
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 6.458381
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 8
# t = 22
# Action: 1
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 6.897007
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 8
# t = 23
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 7.143209
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 8
# t = 24
# Action: 1
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 7.484392
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 8
# t = 25
# Action: 1
# State: (0, 0, 4, 1)
# Reward: 1.000000
# Best Q: 0.000000
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 8
# t = 26
# Action: 1
# State: (0, 0, 4, 1)
# Reward: 1.000000
# Best Q: 0.000000
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 8
# t = 27
# Action: 0
# State: (0, 0, 4, 2)
# Reward: 1.000000
# Best Q: 1.492513
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 8
# t = 28
# Action: 1
# State: (0, 0, 4, 1)
# Reward: 1.000000
# Best Q: 1.238794
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 8
# t = 29
# Action: 0
# State: (0, 0, 4, 2)
# Reward: 1.000000
# Best Q: 1.859459
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 8
# t = 30
# Action: 0
# State: (0, 0, 4, 2)
# Reward: 1.000000
# Best Q: 1.859459
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
# Episode 8 finished after 30.000000 time steps
#
# Episode = 9
# t = 0
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 9.309739
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 1
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 9.763190
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 2
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 9.763190
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 3
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 8.428930
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 4
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 9.779507
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 5
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 9.779507
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 6
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 10.038509
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 7
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 10.358816
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 8
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 10.646868
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 9
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 10.949608
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 10
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 9.555321
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 11
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 11.243490
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 12
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 10.843188
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 13
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 11.243490
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 14
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 11.487122
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 15
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 11.795986
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
# Episode = 9
# t = 16
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 11.795986
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 17
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 11.960758
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 18
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 12.400954
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 19
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 12.536465
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 20
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 12.906028
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 21
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 13.156716
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 22
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 13.465588
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 23
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 13.743824
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 24
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 14.035987
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 25
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 6.302288
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 26
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 6.302288
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 27
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 6.302288
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 28
# Action: 1
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 6.462229
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 29
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 6.849948
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 30
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 7.121839
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 31
# Action: 1
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 7.586230
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 32
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 7.680157
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 33
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 7.484392
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 34
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 7.484392
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 35
# Action: 1
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 7.946970
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 36
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 7.946970
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 37
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 8.407235
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 38
# Action: 1
# State: (0, 0, 4, 2)
# Reward: 1.000000
# Best Q: 2.039829
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 9
# t = 39
# Action: 0
# State: (0, 0, 4, 2)
# Reward: 1.000000
# Best Q: 2.039829
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
# Episode 9 finished after 39.000000 time steps
#
# Episode = 10
# t = 0
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 13.743824
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 10
# t = 1
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 14.175105
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 10
# t = 2
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 14.175105
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 10
# t = 3
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 6.558721
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 10
# t = 4
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 6.558721
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 10
# t = 5
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 13.988150
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 10
# t = 6
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 13.988150
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 10
# t = 7
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 8.865199
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 10
# t = 8
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 10.703494
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 10
# t = 9
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 10.703494
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 10
# t = 10
# Action: 0
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 10.703494
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 10
# t = 11
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 8.865199
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 10
# t = 12
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 8.865199
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 10
# t = 13
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 9.320873
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 10
# t = 14
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 9.774269
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 10
# t = 15
# Action: 1
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 10.225397
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 10
# t = 16
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 10.225397
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 10
# t = 17
# Action: 1
# State: (0, 0, 4, 2)
# Reward: 1.000000
# Best Q: 2.529630
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 10
# t = 18
# Action: 0
# State: (0, 0, 4, 2)
# Reward: 1.000000
# Best Q: 2.529630
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 10
# t = 19
# Action: 0
# State: (0, 0, 4, 2)
# Reward: 1.000000
# Best Q: 3.016982
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
# Episode 10 finished after 19.000000 time steps
#
# Episode = 11
# t = 0
# Action: 0
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 10.463262
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 1
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 10.910946
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 2
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 10.910946
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 3
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 3.120765
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 4
# Action: 0
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 10.910946
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 5
# Action: 0
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 10.910946
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 6
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 11.356391
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 7
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 6.667875
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 8
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 6.667875
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 9
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 12.082574
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 10
# Action: 0
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 12.082574
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 11
# Action: 0
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 12.522161
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 12
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 12.097378
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 13
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 12.967977
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 14
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 12.967977
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 15
# Action: 0
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 12.967977
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 16
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 13.403137
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 17
# Action: 0
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 13.403137
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
# Episode = 11
# t = 18
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 12.336208
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 19
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 13.524484
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 20
# Action: 0
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 13.524484
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 21
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 13.956862
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 22
# Action: 1
# State: (0, 0, 1, 0)
# Reward: 1.000000
# Best Q: 2.166061
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 23
# Action: 1
# State: (0, 0, 1, 0)
# Reward: 1.000000
# Best Q: 2.166061
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 11
# t = 24
# Action: 1
# State: (0, 0, 1, 0)
# Reward: 1.000000
# Best Q: 2.501295
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
# Episode 11 finished after 24.000000 time steps
#
# Episode = 12
# t = 0
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 13.362724
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 12
# t = 1
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 8.252170
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 12
# t = 2
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 8.252170
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 12
# t = 3
# Action: 1
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 10.674270
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 12
# t = 4
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 11.356391
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 12
# t = 5
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 11.356391
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 12
# t = 6
# Action: 0
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 11.356391
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 12
# t = 7
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 11.799609
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 12
# t = 8
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 11.799609
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 12
# t = 9
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 9.161364
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 12
# t = 10
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 9.161364
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 12
# t = 11
# Action: 0
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 13.956862
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 12
# t = 12
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 13.362724
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 12
# t = 13
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 14.092979
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 12
# t = 14
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 14.092979
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 12
# t = 15
# Action: 0
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 14.092979
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 12
# t = 16
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 14.157387
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 12
# t = 17
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 14.157387
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 12
# t = 18
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 14.157387
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 12
# t = 19
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 14.769163
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 12
# t = 20
# Action: 0
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 14.769163
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 12
# t = 21
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 15.195318
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 12
# t = 22
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 15.195318
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 12
# t = 23
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 15.195318
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 12
# t = 24
# Action: 1
# State: (0, 0, 1, 0)
# Reward: 1.000000
# Best Q: 2.988789
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 12
# t = 25
# Action: 1
# State: (0, 0, 1, 0)
# Reward: 1.000000
# Best Q: 2.988789
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 12
# t = 26
# Action: 0
# State: (0, 0, 1, 0)
# Reward: 1.000000
# Best Q: 3.473845
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
# Episode 12 finished after 26.000000 time steps
#
# Episode = 13
# t = 0
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 15.104036
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 13
# t = 1
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 9.623843
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 13
# t = 2
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 15.104036
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 13
# t = 3
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 12.788419
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 13
# t = 4
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 11.799609
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 13
# t = 5
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 10.674270
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 13
# t = 6
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 11.683568
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 13
# t = 7
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 11.683568
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 13
# t = 8
# Action: 0
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 11.834940
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 13
# t = 9
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 10.990439
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 13
# t = 10
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 10.990439
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 13
# t = 11
# Action: 1
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 11.277403
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 13
# t = 12
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 11.577534
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 13
# t = 13
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 11.869581
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 13
# t = 14
# Action: 1
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 12.310233
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 13
# t = 15
# Action: 1
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 12.382332
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 13
# t = 16
# Action: 1
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 12.820421
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 13
# t = 17
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 12.040307
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 13
# t = 18
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 13.088111
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 13
# t = 19
# Action: 1
# State: (0, 0, 4, 1)
# Reward: 1.000000
# Best Q: 2.039829
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 13
# t = 20
# Action: 0
# State: (0, 0, 4, 2)
# Reward: 1.000000
# Best Q: 3.501897
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 13
# t = 21
# Action: 0
# State: (0, 0, 4, 2)
# Reward: 1.000000
# Best Q: 3.501897
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 13
# t = 22
# Action: 0
# State: (0, 0, 4, 2)
# Reward: 1.000000
# Best Q: 3.984387
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
# Episode 13 finished after 22.000000 time steps
#
# Episode = 14
# t = 0
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 15.104036
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 14
# t = 1
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 12.998769
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 14
# t = 2
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 12.998769
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 14
# t = 3
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 10.742584
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 14
# t = 4
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 14.522840
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 14
# t = 5
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 15.195318
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 14
# t = 6
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 15.264886
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 14
# t = 7
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 15.264886
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 14
# t = 8
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 15.317539
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 14
# t = 9
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 15.653778
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 14
# t = 10
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 15.653778
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 14
# t = 11
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 15.653778
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 14
# t = 12
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 15.653778
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 14
# t = 13
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 15.653778
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 14
# t = 14
# Action: 0
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 16.074020
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 14
# t = 15
# Action: 0
# State: (0, 0, 1, 0)
# Reward: 1.000000
# Best Q: 3.473845
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 14
# t = 16
# Action: 1
# State: (0, 0, 1, 0)
# Reward: 1.000000
# Best Q: 3.473845
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
# Episode 14 finished after 16.000000 time steps
#
# Episode = 15
# t = 0
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 12.998769
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 15
# t = 1
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 16.074020
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 15
# t = 2
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 16.074020
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 15
# t = 3
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 16.493650
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 15
# t = 4
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 16.911182
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 15
# t = 5
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 17.326626
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 15
# t = 6
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 17.739993
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 15
# t = 7
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 18.151293
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 15
# t = 8
# Action: 1
# State: (0, 0, 1, 0)
# Reward: 1.000000
# Best Q: 3.956476
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
# Episode 15 finished after 8.000000 time steps
#
# Episode = 16
# t = 0
# Action: 0
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 14.578395
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 16
# t = 1
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 12.310233
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 16
# t = 2
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 12.310233
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 16
# t = 3
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 12.748682
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 16
# t = 4
# Action: 1
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 13.184938
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 16
# t = 5
# Action: 1
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 13.184938
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# Episode = 16
# t = 6
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 14.578395
# Explore rate: 1.000000
# Learning rate: 0.500000
# Streaks: 0
#
#
# ...
# Best Q: 86.697551
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 131
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 86.697551
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 132
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 86.697551
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 133
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 86.720860
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 134
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 86.628521
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 135
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 86.448498
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 136
# Action: 1
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 86.448498
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 137
# Action: 1
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 86.472244
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 138
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 86.697542
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 139
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 86.697542
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 140
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 86.720851
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 141
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 86.623396
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 142
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 86.623396
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 143
# Action: 0
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 86.623396
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 144
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 86.646835
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 145
# Action: 0
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 86.438965
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 146
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 86.747301
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 147
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 86.747301
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 148
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 86.770523
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 149
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 86.628521
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 150
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 86.788190
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 151
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 86.679649
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 152
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 86.792511
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 153
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 86.722568
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 154
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 86.746405
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 155
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 86.746405
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 156
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 86.769628
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 157
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 86.634174
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 158
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 86.803521
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 159
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 86.803521
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 160
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 86.826644
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 161
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 86.749968
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 162
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 86.855464
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 163
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 86.791486
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 164
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 86.788434
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 165
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 86.788434
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 166
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 86.811584
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 167
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 86.686971
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 168
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 86.867398
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 169
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 86.867398
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 170
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 86.890409
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 171
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 86.814101
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 172
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 86.919089
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 173
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 86.855418
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 174
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 86.832136
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 175
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 86.832136
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 176
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 86.855209
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 177
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 86.516215
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
# Episode = 167
# t = 178
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 86.930965
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 179
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 86.930965
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 180
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 86.953865
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 181
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 86.874412
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 182
# Action: 1
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 86.981796
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 183
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 86.981796
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 184
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 86.916039
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 185
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 86.838433
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 186
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 86.838433
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 187
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 86.861495
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 188
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 86.741597
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 189
# Action: 0
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 86.882706
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 190
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 86.789307
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 191
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 87.012014
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 192
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 87.012014
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 193
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 86.925503
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 194
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 86.889489
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 195
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 86.889489
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 196
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 86.912461
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 197
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 86.611789
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 198
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 87.038535
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
#
# Episode = 167
# t = 199
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 87.038535
# Explore rate: 0.175224
# Learning rate: 0.175224
# Streaks: 9
#
# Episode 167 finished after 199.000000 time steps
#
# Episode = 168
# t = 0
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 87.061247
# Explore rate: 0.172631
# Learning rate: 0.172631
# Streaks: 10
#
#
# Episode = 168
# t = 1
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 86.554581
# Explore rate: 0.172631
# Learning rate: 0.172631
# Streaks: 10
#
#
# Episode = 168
# t = 2
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 86.902150
# Explore rate: 0.172631
# Learning rate: 0.172631
# Streaks: 10
#
#
# Episode = 168
# t = 3
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 86.902150
# Explore rate: 0.172631
# Learning rate: 0.172631
# Streaks: 10
#
#
# Episode = 168
# t = 4
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 86.924761
# Explore rate: 0.172631
# Learning rate: 0.172631
# Streaks: 10
#
#
# Episode = 168
# t = 5
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 86.851089
# Explore rate: 0.172631
# Learning rate: 0.172631
# Streaks: 10
#
#
# Episode = 168
# t = 6
# Action: 0
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 86.953417
# Explore rate: 0.172631
# Learning rate: 0.172631
# Streaks: 10
#
#
# Episode = 168
# t = 7
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 86.891276
# Explore rate: 0.172631
# Learning rate: 0.172631
# Streaks: 10
#
#
# Episode = 168
# t = 8
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 87.015472
# Explore rate: 0.172631
# Learning rate: 0.172631
# Streaks: 10
#
#
# Episode = 168
# t = 9
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 87.015472
# Explore rate: 0.172631
# Learning rate: 0.172631
# Streaks: 10
#
#
# Episode = 168
# t = 10
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 87.037887
# Explore rate: 0.172631
# Learning rate: 0.172631
# Streaks: 10
#
#
# Episode = 168
# t = 11
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 86.942165
# Explore rate: 0.172631
# Learning rate: 0.172631
# Streaks: 10
#
#
# Episode = 168
# t = 12
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 86.965319
# Explore rate: 0.172631
# Learning rate: 0.172631
# Streaks: 10
#
#
# Episode = 168
# t = 13
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 86.965319
# Explore rate: 0.172631
# Learning rate: 0.172631
# Streaks: 10
#
#
# Episode = 168
# t = 14
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 86.987821
# Explore rate: 0.172631
# Learning rate: 0.172631
# Streaks: 10
#
#
# Episode = 168
# t = 15
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 86.935131
# Explore rate: 0.172631
# Learning rate: 0.172631
# Streaks: 10
#
#
# Episode = 168
# t = 16
# Action: 0
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 87.019865
# Explore rate: 0.172631
# Learning rate: 0.172631
# Streaks: 10
#
#
# Episode = 168
# t = 17
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 86.709276
# Explore rate: 0.172631
# Learning rate: 0.172631
# Streaks: 10
#
#
# Episode = 168
# t = 18
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 87.062418
# Explore rate: 0.172631
# Learning rate: 0.172631
# Streaks: 10
#
#
# Episode = 168
# t = 19
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 87.062418
# Explore rate: 0.172631
# Learning rate: 0.172631
# Streaks: 10
#
#
# Episode = 168
# t = 20
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 87.084752
# Explore rate: 0.172631
# Learning rate: 0.172631
# Streaks: 10
#
#
# Episode = 168
# t = 21
# Action: 0
# State: (0, 0, 2, 2)
# Reward: 1.000000
# Best Q: 86.968664
# Explore rate: 0.172631
# Learning rate: 0.172631
# Streaks: 10
#
#
# Episode = 168
# t = 22
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 86.637193
# Explore rate: 0.172631
# Learning rate: 0.172631
# Streaks: 10
#
#
# Episode = 168
# t = 23
# Action: 1
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 86.637193
# Explore rate: 0.172631
# Learning rate: 0.172631
# Streaks: 10
#
#
# Episode = 168
# t = 24
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 86.989191
# Explore rate: 0.172631
# Learning rate: 0.172631
# Streaks: 10
#
#
# Episode = 168
# t = 25
# Action: 0
# State: (0, 0, 3, 2)
# Reward: 1.000000
# Best Q: 86.739505
# Explore rate: 0.172631
# Learning rate: 0.172631
# Streaks: 10
#
#
# Episode = 168
# t = 26
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 86.989191
# Explore rate: 0.172631
# Learning rate: 0.172631
# Streaks: 10
#
#
# Episode = 168
# t = 27
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 86.989191
# Explore rate: 0.172631
# Learning rate: 0.172631
# Streaks: 10
#
#
# Episode = 168
# t = 28
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 87.011652
# Explore rate: 0.172631
# Learning rate: 0.172631
# Streaks: 10
#
#
# Episode = 168
# t = 29
# Action: 1
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 87.034074
# Explore rate: 0.172631
# Learning rate: 0.172631
# Streaks: 10
#
#
# Episode = 168
# t = 30
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 86.972167
# Explore rate: 0.172631
# Learning rate: 0.172631
# Streaks: 10
#
#
# Episode = 168
# t = 31
# Action: 0
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 87.064396
# Explore rate: 0.172631
# Learning rate: 0.172631
# Streaks: 10
#
#
# Episode = 168
# t = 32
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 87.010419
# Explore rate: 0.172631
# Learning rate: 0.172631
# Streaks: 10
#
#
# Episode = 168
# t = 33
# Action: 0
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 87.077502
# Explore rate: 0.172631
# Learning rate: 0.172631
# Streaks: 10
#
#
# Episode = 168
# t = 34
# Action: 1
# State: (0, 0, 3, 0)
# Reward: 1.000000
# Best Q: 87.044308
# Explore rate: 0.172631
# Learning rate: 0.172631
# Streaks: 10
#
#
# Episode = 168
# t = 35
# Action: 0
# State: (0, 0, 3, 1)
# Reward: 1.000000
# Best Q: 87.094137
# Explore rate: 0.172631
# Learning rate: 0.172631
# Streaks: 10
#
#
# Episode = 168
# t = 36
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 86.792574
# Explore rate: 0.172631
# Learning rate: 0.172631
# Streaks: 10
#
#
# Episode = 168
# t = 37
# Action: 0
# State: (0, 0, 2, 1)
# Reward: 1.000000
# Best Q: 87.105655
# Explore rate: 0.172631
# Learning rate: 0.172631
# Streaks: 10
#
#
# Episode = 168
# t = 38
# Action: 1
# State: (0, 0, 2, 0)
# Reward: 1.000000
# Best Q: 86.868881
# Explore rate: 0.172631
# Learning rate: 0.172631
# Streaks: 10
